# %% [markdown]
# *Hossein Fatheddin*
# Light Curve Plot for Exoplanet **K2-2113**(Kepler Telescope)

# %% [markdown]
# For More Data on Exoplanets:
#     https://exoplanetarchive.ipac.caltech.edu/docs/data.html

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('211311380-c05_kepler_Data.xlsx')
df
# Out:
#                 A         B
# 0     2307.550487  0.998291
# 1     2307.570919  0.998452
# 2     2307.591351  0.998505
# 3     2307.611783  0.998540
# 4     2307.632215  0.998534
# ...           ...       ...
# 3397  2381.309196  1.001959
# 3398  2381.350060  1.002019
# 3399  2381.370492  1.001949
# 3400  2381.390924  1.002003
# 3401  2381.411356  1.001900
#
# [3402 rows x 2 columns]

# %%
plt.plot(df['A'], df['B'],'b',label='Transit')
#plt.axis([2350,2360,0.994,1.004]) #Zoom-in
plt.xlabel('Time')
plt.ylabel('Stellar luminosity')
plt.legend()

# %%
plt.plot(df['A'], df['B'],'b',label='Transit')
plt.axis([2350,2360,0.994,1.004]) #Zoom-in
plt.xlabel('Time')
plt.ylabel('Stellar luminosity')
plt.legend()

# %%
plt.plot(df['A'], df['B'],'b',label='Transit')
plt.axis([2300,2320,0.994,1.004]) #Zoom-in
plt.xlabel('Time')
plt.ylabel('Stellar luminosity')
plt.legend()

# %%
plt.plot(df['A'], df['B'],'b',label='Transit')
plt.axis([2330,2340,0.994,1.004]) #Zoom-in
plt.xlabel('Time')
plt.ylabel('Stellar luminosity')
plt.legend()
